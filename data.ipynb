# %%
import os

import numpy as np
import pandas as pd

# %%
synopsisdf = pd.read_excel('./synopsis_data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9927/2506420054.py in <module>
# ----> 1 synopsisdf = pd.read_excel('./synopsis_data.xlsx')
#
# ~/anaconda3/envs/ym/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/envs/ym/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
# ...

# %%
moviedf = pd.read_excel('./movie_info.xlsx')
staticdf = pd.read_excel('./open_static.xlsx')

# %%
synopsisdf
# Out:
# Empty DataFrame
# Columns: [title, code, synopsis]
# Index: []

# %%
moviedf.head()
# Out:
#              영화명                    영화명(영문)  제작연도 제작국가  유형        장르  제작상태  \
# 0      콘크리트 유토피아                        NaN  2021   한국  장편       드라마  개봉예정
# 1  마마무: 마이콘 더 무비  MAMAMOO: MY CON THE MOVIE  2023   한국  장편  공연,다큐멘터리    개봉
# 2            귀공자                 The Childe  2022   한국  장편        액션    개봉
# 3     제이홉 인 더 박스          j-hope IN THE BOX  2023   한국  장편     다큐멘터리    개봉
# 4        대치동 스캔들                        NaN  2023   한국  장편       NaN    기타
#
#     감독                           제작사
# 0  엄태화  클라이맥스 스튜디오(주),(주)비에이치 엔터테인먼트
# 1  임재경                 드림엔진스튜디오 주식회사
# 2  박훈정           (주)영화사 금월,(주)스튜디오앤뉴
# 3  박준수                        (주)하이브
# 4  김수인                           NaN

# %%
staticdf.head()
# Out:
#    순번         영화명           감독                             제작사  \
# 0   1          명량          김한민                       (주)빅스톤픽쳐스
# 1   2        극한직업          이병헌  (주)어바웃잇,영화사 해그림 주식회사,(주)씨제이이엔엠
# 2   3   신과함께-죄와 벌          김용화          리얼라이즈픽쳐스(주),(주)덱스터스튜디오
# 3   4        국제시장          윤제균             (주)제이케이필름,(주)씨제이이엔엠
# 4   5  어벤져스: 엔드게임  안소니 루소,조 루소                             NaN
#
#                   수입사                 배급사        개봉일  영화유형 영화형태  국적  전국 스크린수  \
# 0                 NaN           (주)씨제이이엔엠 2014-07-30  개봉영화   장편  한국     1587
# 1                 NaN           (주)씨제이이엔엠 2019-01-23  개봉영화   장편  한국     1978
# 2                 NaN       롯데쇼핑㈜롯데엔터테인먼트 2017-12-20  개봉영화   장편  한국     1912
# 3                 NaN           (주)씨제이이엔엠 2014-12-17  개봉영화   장편  한국      966
# 4  월트디즈니컴퍼니코리아 유한책임회사  월트디즈니컴퍼니코리아 유한책임회사 2019-04-24  개봉영화   장편  미국     2835
#
#          전국 매출액    전국 관객수        서울 매출액   서울 관객수   장르        등급  영화구분
# ...

# %%
moviedf.columns = ['title', 'title_en', 'year', 'country', 'type', 'genre', '']

# %%
print(synopsisdf.shape)
print(moviedf.shape)
print(staticdf.shape)
# Out:
# (0, 3)
# (81419, 9)
# (25008, 18)

# %%
merge_inner = pd.merge(moviedf, staticdf) # inner, 교집합

# %%
merge_left = pd.merge(df1,df2, how='left', left_on='stock_name', right_on='name')
